# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/augmento_scores_df.csv")

# %%
df.head(6)
# Out:
#      datetime                                         BTC_counts  \
# 0  2018-02-01  [30, 199, 207, 200, 53, 150, 20, 1, 2, 54, 24,...
# 1  2018-02-02  [40, 217, 142, 275, 123, 126, 31, 2, 5, 93, 15...
# 2  2018-02-03  [25, 181, 145, 177, 47, 96, 14, 3, 4, 53, 17, ...
# 3  2018-02-04  [25, 159, 114, 151, 36, 88, 19, 1, 1, 23, 7, 3...
# 4  2018-02-05  [29, 202, 174, 231, 56, 97, 29, 2, 6, 81, 18, ...
# 5  2018-02-06  [16, 190, 190, 298, 76, 85, 34, 3, 1, 105, 25,...
#
#                                       twitter_counts  \
# 0  [19, 35, 53, 179, 26, 44, 22, 5, 22, 83, 22, 4...
# 1  [30, 42, 51, 173, 43, 29, 28, 12, 21, 144, 35,...
# 2  [11, 20, 91, 91, 12, 70, 10, 16, 20, 48, 25, 3...
# 3  [13, 22, 86, 87, 12, 45, 21, 4, 19, 46, 28, 36...
# 4  [14, 35, 180, 155, 21, 35, 39, 3, 16, 143, 23,...
# 5  [7, 43, 202, 169, 29, 47, 37, 14, 26, 159, 19,...
#
#                                        reddit_counts  BTC_score  \
# 0  [25, 142, 143, 330, 60, 90, 107, 2, 12, 90, 32...   0.496911
# ...
