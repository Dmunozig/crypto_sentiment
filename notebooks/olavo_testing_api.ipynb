# %%
from crypto_project.data import price_and_indexes
from crypto_project.model import fit_model,future_dataframe,model_predict, train_test_split

# %%
dataframe = price_and_indexes(local=False)

# %%
dataframe
# Out:
#              ds           y Fear&Greed
# 0    2018-02-01   9052.5763         30
# 1    2018-02-02   8827.6300         15
# 2    2018-02-03   9224.3913         40
# 3    2018-02-04   8186.6488         24
# 4    2018-02-05   6914.2600         11
# ...         ...         ...        ...
# 1123 2021-03-03  50422.1683         78
# 1124 2021-03-04  48365.1450         84
# 1125 2021-03-05  48780.9600         77
# 1126 2021-03-06  48887.0233         77
# 1127 2021-03-07  50985.9417         76
#
# [1128 rows x 3 columns]

# %%
train, test = train_test_split(dataframe)

# %%
train
# Out:
#              ds           y Fear&Greed
# 0    2018-02-01   9052.5763         30
# 1    2018-02-02   8827.6300         15
# 2    2018-02-03   9224.3913         40
# 3    2018-02-04   8186.6488         24
# 4    2018-02-05   6914.2600         11
# ...         ...         ...        ...
# 1122 2021-03-02  48502.8083         78
# 1123 2021-03-03  50422.1683         78
# 1124 2021-03-04  48365.1450         84
# 1125 2021-03-05  48780.9600         77
# 1126 2021-03-06  48887.0233         77
#
# [1127 rows x 3 columns]

# %%
fitted_model = fit_model(train,local=False)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
model_future = future_dataframe(train,fitted_model, local=False)

# %%
model_future
# Out:
#              ds Fear&Greed
# 0    2018-02-01         30
# 1    2018-02-02         15
# 2    2018-02-03         40
# 3    2018-02-04         24
# 4    2018-02-05         11
# ...         ...        ...
# 1123 2021-03-03         78
# 1124 2021-03-04         84
# 1125 2021-03-05         77
# 1126 2021-03-06         77
# 1127 2021-03-07        NaN
#
# [1128 rows x 2 columns]

# %%
model_predict(fitted_model, model_future)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-8adaf153d678> in <module>
# ----> 1 model_predict(fitted_model, model_future)
#
# ~/code/Dmunozig/crypto_sentiment/crypto_project/model.py in model_predict(fitted_model, model_future)
#      62 def model_predict(fitted_model, model_future):
#      63
# ---> 64     prediction_dataframe = fitted_model.predict(model_future)
#      65     prediction = prediction_dataframe["yhat"][-1:].values[0]
#      66     return prediction
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/fbprophet/forecaster.py in predict(self, df)
#    1197             if df.shape[0] == 0:
#    1198                 raise ValueError('Dataframe has no rows.')
# -> 1199             df = self.setup_dataframe(df.copy())
#    1200
#    1201         df['trend'] = self.predict_trend(df)
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/fbprophet/forecaster.py in setup_dataframe(self, df, initialize_scales)
#     276             df[name] = pd.to_numeric(df[name])
#     277             if df[name].isnull().any():
# --> 278                 raise ValueError(
#     279                     'Found NaN in column {name!r}'.format(name=name)
#     280                 )
#
# ValueError: Found NaN in column 'Fear&Greed'
