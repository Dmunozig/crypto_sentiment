# %%
from crypto_project.data import price_and_indexes

# %%
df = price_and_indexes()

# %%
df
# Out:
#              btc_price  Fear&Greed  \
# timestamp
# 2018-02-01   9052.5763          30
# 2018-02-02   8827.6300          15
# 2018-02-03   9224.3913          40
# 2018-02-04   8186.6488          24
# 2018-02-05   6914.2600          11
# ...                ...         ...
# 2021-01-27  30425.3933          78
# 2021-01-28  33420.0450          55
# 2021-01-29  34264.0100          77
# 2021-01-30  34324.2717          76
# 2021-01-31  33129.7433          78
#
#                                                    BTC_counts  \
# timestamp
# 2018-02-01  [30, 199, 207, 200, 53, 150, 20, 1, 2, 54, 24,...
# 2018-02-02  [40, 217, 142, 275, 123, 126, 31, 2, 5, 93, 15...
# 2018-02-03  [25, 181, 145, 177, 47, 96, 14, 3, 4, 53, 17, ...
# 2018-02-04  [25, 159, 114, 151, 36, 88, 19, 1, 1, 23, 7, 3...
# 2018-02-05  [29, 202, 174, 231, 56, 97, 29, 2, 6, 81, 18, ...
# ...                                                       ...
# 2021-01-27  [6, 24, 36, 41, 16, 45, 7, 2, 3, 10, 21, 9, 14...
# ...

# %%
api_df = price_and_indexes(local=False)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ...

# %%
api_df
